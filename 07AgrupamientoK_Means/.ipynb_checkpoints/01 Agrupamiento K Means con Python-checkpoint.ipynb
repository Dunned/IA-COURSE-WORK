# %% [markdown]
# # Agrupamiento K Means con Python
#
# Agrupamiento K Means es un algoritmo de aprendizaje no supervisado que intenta agrupar los datos en función de su similitud. El aprendizaje no supervisado significa que no hay ningún resultado que predecir, y el algoritmo simplemente trata de encontrar patrones en los datos. En el agrupamiento K Means, tenemos que especificar el número de clusters en los que queremos agrupar los datos. El algoritmo asigna aleatoriamente cada observación a un clúster y encuentra el centroide de cada clúster. Luego, el algoritmo itera a través de dos pasos:
# Reasigna los puntos de datos al clúster cuyo centroide es el más cercano. Calcula el nuevo centroide de cada grupo. Estos dos pasos se repiten hasta que la variación dentro del clúster no se puede reducir más. La variación dentro del clúster se calcula como la suma de la distancia euclidiana entre los puntos de datos y sus respectivos centroides de clúster.

# %% [markdown]
# ## Importación de Librerias

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Creación de algunos datos

# %%
from sklearn.datasets import make_blobs

# %%
# Creación de datos
data0 = make_blobs(n_samples=5, n_features=2, 
                           centers=3, cluster_std=1.8,random_state=101)
data0[0]
# Out:
# array([[  4.04519119,   5.31196755],
#        [  1.49998486,   0.83857926],
#        [-13.06321831,  -5.23734717],
#        [ -8.47865118,  -7.62976784],
#        [ -1.19856602,   2.50408937]])

# %%
data0[1]
# Out:
# array([2, 0, 1, 1, 0])

# %%
data0[0][:,1]
# Out:
# array([ 5.31196755,  0.83857926, -5.23734717, -7.62976784,  2.50408937])

# %%
plt.scatter(data0[0][:,0],data0[0][:,1],c=data0[1],cmap='rainbow')

# %%
# Creación de datos
data = make_blobs(n_samples=300, n_features=2, 
                           centers=4, cluster_std=1.8,random_state=101)

# %% [markdown]
# ## Visualización de datos

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# ## Creación de Clústeres

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 4.18620177,  6.80055146],
#        [-9.51083714, -6.50944858],
#        [-3.67618674,  7.59124984],
#        [ 0.22590361,  2.10954545]])

# %%
kmeans.labels_
# Out:
# array([2, 0, 3, 2, 2, 1, 3, 3, 3, 0, 3, 3, 3, 2, 1, 0, 1, 2, 3, 3, 1, 1,
#        1, 2, 3, 2, 0, 2, 1, 0, 3, 3, 3, 3, 0, 0, 2, 3, 3, 0, 1, 0, 0, 2,
#        1, 2, 1, 3, 2, 3, 0, 3, 0, 0, 2, 1, 1, 1, 2, 0, 1, 2, 2, 0, 1, 2,
#        2, 3, 3, 2, 1, 2, 3, 1, 1, 0, 0, 3, 0, 1, 2, 3, 3, 1, 3, 3, 3, 3,
#        1, 1, 1, 1, 1, 1, 3, 0, 1, 3, 2, 3, 3, 1, 3, 2, 2, 2, 2, 1, 3, 3,
#        3, 0, 3, 2, 1, 3, 1, 3, 2, 2, 1, 1, 3, 2, 3, 2, 2, 0, 0, 2, 2, 0,
#        2, 2, 1, 3, 3, 3, 2, 0, 2, 0, 0, 0, 1, 2, 0, 0, 2, 0, 2, 3, 1, 0,
#        0, 1, 2, 1, 0, 2, 1, 0, 1, 3, 0, 3, 3, 3, 2, 2, 0, 1, 1, 0, 3, 3,
#        2, 1, 0, 2, 0, 1, 3, 3, 3, 0, 2, 1, 3, 0, 1, 0, 2, 3, 0, 3, 0, 2,
#        0, 3, 0, 0, 3, 0, 2, 2, 2, 3, 1, 2, 1, 3, 3, 3, 2, 1, 3, 1, 0, 3,
#        1, 0, 0, 2, 2, 2, 3, 0, 2, 2, 3, 3, 3, 1, 3, 0, 2, 1, 1, 0, 2, 3,
#        1, 2, 1, 2, 3, 1, 0, 3, 0, 1, 1, 0, 3, 3, 3, 1, 2, 1, 3, 2, 1, 1,
#        1, 2, 1, 1, 1, 0, 0, 3, 2, 0, 0, 2, 1, 2, 0, 0, 3, 1, 2, 1, 0, 3,
#        2, 1, 1, 1, 3, 0, 1, 0, 0, 1, 3, 0, 2, 3])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# Debe tener en cuenta que los colores carecen de significaco en relación entre las dos columnas.

# %% [markdown]
# # ¡Buen trabajo!
