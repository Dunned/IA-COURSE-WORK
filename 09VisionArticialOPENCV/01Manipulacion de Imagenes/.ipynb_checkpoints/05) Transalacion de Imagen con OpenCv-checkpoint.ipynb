# %% [markdown]
# ¡OPEN-CV
# <span style="font-family:Papyrus; font-size:30px">  TRANSLACIÓN DE  IMAGENES !</span>
#
# #### JAUREGUI ROMERO EDUARDO RAFAEL - 19200082

# %% [markdown]
# ### Importar Librerias

# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in /Users/eduardojauregui/opt/anaconda3/lib/python3.9/site-packages (0.5.4)

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
import imutils

# %% [markdown]
# ## FUNCION PARA MOSTRAR IMAGENES

# %%
def mostrar_imagen(titulo,imagen):
    imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)
    plt.imshow(imagen)
    plt.title(titulo)
    plt.grid(False)
    plt.show

# %% [markdown]
# ## Image translation with OpenCV

# %%
args = {
"image": "peru.jpeg"
}

# %%
# cargar la imagen y mostrarla
image = cv2.imread(args["image"])
mostrar_imagen("Original", image)

# %%
image.shape # TAMAÑO Y CAPAS
# Out:
# (330, 580, 3)

# %%
# trasladar la imagen 25 pixeles a la derecha y 50 pixeles hacia abajo

M = np.float32([[1, 0, 25], [0, 1, 50]]) #25 PIXELELES A LA DERECHA , 50 PIXELES ABAJO
shifted = cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))
mostrar_imagen("Trasladado hacia Abajo y a la Derecha", shifted)

# %%
# ahora, trasladar la imagen 50 pixeles a la izquierda y 90 pixeles
# hacia arriba, usando valores negativos para las direcciones x e y
# respectivamente
M = np.float32([[1, 0, -50], [0, 1, -90]])
shifted = cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))
mostrar_imagen("Trasladado hacia arriba y hacia la izquierda", shifted)

# %% [markdown]
# ## USANDO IMUTILS

# %%
# uso de la función de ayuda de imutils para trasladar la imagen 100
# pixeles hacia abajo en una simple llamada de función
shifted = imutils.translate(image, 50, 100)  # IMAGEN,X,Y
mostrar_imagen("Trasladado hacia abajo", shifted)

# %%
# uso de la función de ayuda de imutils para trasladar la imagen 100,200
# pixeles hacia abajo en una simple llamada de función
shifted = imutils.translate(image, 100, 200)  # IMAGEN,X,Y
mostrar_imagen("Trasladado hacia abajo", shifted)

# %%
# uso de la función de ayuda de imutils para trasladar la imagen -50,-100
# pixeles hacia abajo en una simple llamada de función
shifted = imutils.translate(image, -50,-100) #imagen,x,y
mostrar_imagen("Trasladado hacia abajo", shifted)
